# %%
pip install pandas matplotlib plotly pytrends seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: plotly in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (6.1.2)
# Requirement already satisfied: pytrends in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (4.9.2)
# Requirement already satisfied: seaborn in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from plotly) (1.43.1)
# Requirement already satisfied: requests>=2.0 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: lxml in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from pytrends) (5.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0->pytrends) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0->pytrends) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0->pytrends) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vishal jadhav\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0->pytrends) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pytrends.request import TrendReq

# %% [markdown]
# # setup pytrend library and define keyword

# %%
pytrends = TrendReq(hl = 'en-us', tz = 360)
keyword = "cricket"

# %% [markdown]
# # Data Request

# %%
pytrends.build_payload([keyword], cat = 0, timeframe = 'today 12-m', geo = '', gprop = '')

# %% [markdown]
# # Country wise Interest

# %%
region_data = pytrends.interest_by_region()
region_data = region_data.sort_values(by = keyword,ascending = False).head(15)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = region_data[keyword], y = region_data.index, palette = "Blues_d")
plt.title(f"Top Countries searching for '{keyword}' ")
plt.xlabel("Interest")
plt.ylabel("Country")
plt.show()
# Out:
# C:\Users\Vishal Jadhav\AppData\Local\Temp\ipykernel_6716\4237842116.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # World Map

# %%
region_data = region_data.reset_index()
fig = px.choropleth(region_data,
                    locations = 'geoName',
                    locationmode = 'country names',
                    color = keyword,
                    title = f"Search Interest for '{keyword}' by Country",
                    color_continuous_scale = 'Blues')
fig.show()

# %% [markdown]
# # Time Wise Interest

# %%
time_df = pytrends.interest_over_time()
# Out:
# C:\Users\Vishal Jadhav\AppData\Local\Programs\Python\Python313\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
plt.figure(figsize = (12,6))
plt.plot(time_df.index, time_df[keyword], marker = 'o', color = 'purple')
plt.title(f"Search interest over time '{keyword}' ")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.grid(True)
plt.show()

# %% [markdown]
# # Multiple keywords compare

# %%
kw_list = ["cricket", "data science", "machine learning"]
pytrends.build_payload(kw_list, cat = 0, timeframe = 'today 12-m', geo = '', gprop = '')

# %%
compare_df = pytrends.interest_over_time()

plt.figure(figsize = (12,6))
for kw in kw_list:
    plt.plot(compare_df.index, compare_df[kw], label = kw)

plt.title("keyword comparison over time")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Vishal Jadhav\AppData\Local\Programs\Python\Python313\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
